# %%
import pandas as pd
data_path = r'C:\Users\gyh14\nlp\comp3225_example_package\ontonotes_parsed.json'
ontonotes = pd.read_json(data_path)

# %%
ontonotes.head()
# Out:
#   C:\projects\datasets\ontonotes-release-5\ontonotes-release-5.0\data\files\data\english\annotations\bc\cctv\00\cctv_0000
# 0  {'tokens': ['In', 'the', 'summer', 'of', '2005...                                                                       \
# 1  {'tokens': ['With', 'their', 'unique', 'charm'...
# 2  {'tokens': ['The', 'world', ''s', 'fifth', 'Di...
# 3  {'tokens': ['The', 'most', 'important', 'thing...
# 4  {'tokens': ['Well', ',', 'for', 'several', 'ye...
#
#   C:\projects\datasets\ontonotes-release-5\ontonotes-release-5.0\data\files\data\english\annotations\bc\cctv\00\cctv_0001
# 0  {'tokens': ['What', 'kind', 'of', 'memory', '?...                                                                       \
# 1  {'tokens': ['We', 'respectfully', 'invite', 'y...
# 2  {'tokens': ['WW', 'II', 'Landmarks', 'on', 'th...
# 3  {'tokens': ['Standing', 'tall', 'on', 'Taihang...
# 4  {'tokens': ['It', 'is', 'composed', 'of', 'a',...
#
# ...
